# %%
from neo4j import GraphDatabase

# %%
URI = 'bolt://localhost:7687'
AUTH = ('neo4j', 'password')

# %%
"""
UNWIND is a Cypher clause that converts a list into individual rows. It's like "unrolling" a 
collection into separate records.
"""
query = '''
    UNWIND $trackInfos AS trackInfo
    CREATE (track:Track {id: trackInfo.id})
    SET track.name = trackInfo.name
    RETURN track
    '''

# %%
def create_tracks(driver, tracks):
    records, _, _ = driver.execute_query(
        query,
        trackInfos = tracks,
        database_ = 'testload'
        )
    for record in records:
        print(record['track']['name'])

# %%
with GraphDatabase.driver(URI, auth=AUTH) as driver:
    all_tracks = []
    all_tracks.append({'id': 'track-01', 'name': 'Sin City'})
    all_tracks.append({'id': 'track-02', 'name': 'Creep'})

    create_tracks(driver, all_tracks)
# Out:
# ---------------------------------------------------------------------------
# ConstraintError                           Traceback (most recent call last)
# Cell In[5], line 6
#       3 all_tracks.append({'id': 'track-01', 'name': 'Sin City'})
#       4 all_tracks.append({'id': 'track-02', 'name': 'Creep'})
# ----> 6 create_tracks(driver, all_tracks)
#
# Cell In[4], line 2, in create_tracks(driver, tracks)
#       1 def create_tracks(driver, tracks):
# ----> 2     records, _, _ = driver.execute_query(
#       3         query,
#       4         trackInfos = tracks,
#       5         database_ = 'testload'
#       6         )
#       7     for record in records:
#       8         print(record['track']['name'])
#
# File C:\Python310\lib\site-packages\neo4j\_sync\driver.py:970, in Driver.execute_query(self, query_, parameters_, routing_, database_, impersonated_user_, bookmark_manager_, auth_, result_transformer_, **kwargs)
#     966     raise ValueError(
# ...
